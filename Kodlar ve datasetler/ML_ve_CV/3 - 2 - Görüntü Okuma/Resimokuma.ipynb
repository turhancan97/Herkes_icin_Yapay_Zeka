# %% [markdown]
# #**Python ile Görüntü İşlemeye Giriş**
# Kodluyoruz Liseler Yapay Zeka ile Buluşuyor - Uygulaması
#
#
# >Bu uygulama OpenCV bilgisayarlı görü kütüphanesi ve veri analiz kütüphanelerinde yer alan basit teknikleri kullanarak Python dilinde oluşturulmuş alıştırmalar içermektedir.
#
# *The source of this notebook is located at https://github.com/xn2333/OpenCV/blob/master/Seminar_Image_Processing_in_Python.ipynb*
#
# *Colab hakkında daha fazla bilgi için: [Colab](https://colab.research.google.com/notebooks/welcome.ipynb)*
#
# *OpenCV hakkında daha fazla bilgi için: [OpenCV](https://opencv.org/)*

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##1.Adım: Bağımlılıkları Yükleme
#
# > Bu bölümde kullanacağımız fonksiyonlar için gerekli bağımlılıkları indireceğiz: **numpy**,  **cv2**, **matplotlib**
#
# *   [Numpy](https://www.numpy.org/) doğrusal cebir ve rastgele sayı yetenekleri için kullanılan bir dizi işleme kütüphanesidir.
# *   [CV2](https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_gui/py_image_display/py_image_display.html) bilgisayarla görme görevleri için kullanılan OpenCV kütüphanesidir.
# *   [Matplotlib](https://matplotlib.org/) şekiller oluşturan ve grafiksel kullanıcı arayüzü araç seti sağlayan bir kütüphanedir.

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ##2.Adım: Bilgisayardan Resim okuma
#
# > Bu adımda bilgisayarımızdaki bir dosyadan resimleri okuyacağız ve bunları openCV kullanarak görüntüleyeceğiz.

# %%
from google.colab import files
from IPython.display import Image
from google.colab.patches import cv2_imshow # resim gösterimi için

# %%
uploaded=files.upload() #Bilgisayarımızdan dosya yüklüyoruz
# Out:
#      <input type="file" id="files-b39efc3f-288a-445b-904c-faa09c1a96b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b39efc3f-288a-445b-904c-faa09c1a96b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 56401.jpg to 56401.jpg

# %%
Image('56401.jpg') #Yüklediğimiz dosya ekrana geliyor
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Image('56401.jpg',width=200) #Gösterilen resmin genişliğini 200 piksel olarak ayarladık.
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##3.Adım: Drive'dan Resim Okuma ve Değişkene Kaydetme
#
# > Bu adımda Drive'a daha önceden kayıtlı resimleri okuyacağız ve bunları openCV kullanarak görüntüleyeceğiz.

# %%
# !ls '/content/gdrive/MyDrive/KodluyoruzBilgisayarliGoru'
# Out:
#  1.0.Opencv_Resimokuma.ipynb
#  1.1.Opencv_ResimOkuma_Plt.ipynb
#  2.0.Opencv_temel_islemler1.ipynb
#  2.1.Opencv_ROI.ipynb
#  2.2.Opencv_Toplama.ipynb
#  2.3.Opencv_GeometrikIslemler.ipynb
#  3.0.Opencv_Yumusatma.ipynb
#  3.1.Opencv_GurultuGiderme.ipynb
#  4.0YuzTanima.ipynb
#  56401.jpg
#  5.RenkliCisimAlgilama.ipynb
#  65c832d202a503b15d99e628f4313782f3ef50db-300x62.png
#  affine.jpg
#  filter.jpg
#  haarcascade_eye.xml
#  haarcascade_frontalface_default.xml
# 'Herkes İçin Yapay Zeka'
#  Maskot.jpg
#  median.jpg
#  messi.jpg
#  perspective.jpg
#  Untitled0.ipynb
#  Video.ipynb
#  yesilcam.jpg

# %%
Image('/content/gdrive/MyDrive/KodluyoruzBilgisayarliGoru/56401.jpg')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
resim=cv2.imread('/content/gdrive/MyDrive/KodluyoruzBilgisayarliGoru/56401.jpg')

# %%
print(type(resim))

# %%
print(resim)

# %% [markdown]
# ## 4.Adım: MATPLOTLİB kullanarak resmi gösterme

# %%
# Load in Grayscale
resim = cv2.imread('/content/gdrive/MyDrive/KodluyoruzBilgisayarliGoru/56401.jpg')

plt.imshow(resim)
plt.show()

# %% [markdown]
# ## 5.Adım: wget ile URL 'den Resim Okuma
#
# > Bu adımda url'lerdeki resimleri okuyacağız ve bunları openCV kullanarak görüntüleyeceğiz.

# %%
# !wget "https://www.ceyrekmuhendis.com/wp-content/uploads/2020/07/kapak_800x445.jpg" -O dt.jpg
# Out:
# --2021-01-10 10:55:12--  https://www.ceyrekmuhendis.com/wp-content/uploads/2020/07/kapak_800x445.jpg
# Resolving www.ceyrekmuhendis.com (www.ceyrekmuhendis.com)... 78.142.208.51
# Connecting to www.ceyrekmuhendis.com (www.ceyrekmuhendis.com)|78.142.208.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76685 (75K) [image/jpeg]
# Saving to: ‘dt.jpg’
#
# dt.jpg              100%[===================>]  74.89K   249KB/s    in 0.3s
#
# 2021-01-10 10:55:13 (249 KB/s) - ‘dt.jpg’ saved [76685/76685]
