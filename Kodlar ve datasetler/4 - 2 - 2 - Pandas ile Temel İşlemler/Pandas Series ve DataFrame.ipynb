# %%
import pandas as pd
import numpy as np

# %%
pd.Series([10,20,30,40,50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = np.array([10,20,30,40,50])
seri = pd.Series(data)
seri
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = np.array([10,20,30,40,50])
seri = pd.Series(data, index = [100,101,102,103,104])
seri
# Out:
# 100    10
# 101    20
# 102    30
# 103    40
# 104    50
# dtype: int64

# %%
data2 = {'a':0, 'b':1, 'c':2}

# %%
seri2 = pd.Series(data2)
seri2
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
seri2[0]
# Out:
# 0

# %%
seri2[0:2]
# Out:
# a    0
# b    1
# dtype: int64

# %%
seri2['b']
# Out:
# 1

# %%
seri2[['a','b','c']]
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
seri2['a':'d']
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
data = np.array([10,20,30,40,50])
seri = pd.Series(data, index = ['a','b','c','d','e'])
seri
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
seri['a']
# Out:
# 10

# %%
seri['a'] = 90

# %%
seri
# Out:
# a    90
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
seri.sum()
# Out:
# 230

# %%
seri.max()
# Out:
# 90

# %%
seri.mean()
# Out:
# 46.0

# %%
seri.median()
# Out:
# 40.0

# %%
isimler = ["Ali","Buse","Ceren","Deniz","Emre"]

# %%
df = pd.DataFrame(isimler, columns = ["İsimler"])
df
# Out:
#   İsimler
# 0     Ali
# 1    Buse
# 2   Ceren
# 3   Deniz
# 4    Emre

# %%
data = {'Şehirler': ['Ankara','Bursa','Denizli','Eskişehir'],
        'Plakalar': [6, 16, 20, 26]}
data
# Out:
# {'Plakalar': [6, 16, 20, 26],
#  'Şehirler': ['Ankara', 'Bursa', 'Denizli', 'Eskişehir']}

# %%
df = pd.DataFrame(data, index = ['a','b','c','d'])
df
# Out:
#     Şehirler  Plakalar
# a     Ankara         6
# b      Bursa        16
# c    Denizli        20
# d  Eskişehir        26

# %%
df["havadurumu"] = pd.Series([33,26,40,36], index = ['a','b','c','d'])

# %%
df
# Out:
#     Şehirler  Plakalar  havadurumu
# a     Ankara         6          33
# b      Bursa        16          26
# c    Denizli        20          40
# d  Eskişehir        26          36

# %%
df.drop("havadurumu", axis = 1)
# Out:
#     Şehirler  Plakalar
# a     Ankara         6
# b      Bursa        16
# c    Denizli        20
# d  Eskişehir        26

# %%
df
# Out:
#     Şehirler  Plakalar  havadurumu
# a     Ankara         6          33
# b      Bursa        16          26
# c    Denizli        20          40
# d  Eskişehir        26          36

# %%
df.drop("havadurumu", axis = 1, inplace = True)

# %%
df
# Out:
#     Şehirler  Plakalar
# a     Ankara         6
# b      Bursa        16
# c    Denizli        20
# d  Eskişehir        26

# %%
df.drop('a', axis = 0, inplace = True)

# %%
df
# Out:
#     Şehirler  Plakalar
# b      Bursa        16
# c    Denizli        20
# d  Eskişehir        26

# %%
df.loc["b":"d"]
# Out:
#     Şehirler  Plakalar
# b      Bursa        16
# c    Denizli        20
# d  Eskişehir        26

# %%
df.iloc[1:3]
# Out:
#     Şehirler  Plakalar
# c    Denizli        20
# d  Eskişehir        26

# %%
data = {'isimler': ["Ali","Buse","Ceren","Deniz","Emre","Furkan","Gizem","Hakan"],
        'Ogr_No': [100, 101, 102, 103, 104, 105, 106, 107],
        'Fizik': pd.Series([90, 88, 75, 92, 100, 81, 77, 63]),
        'Matematik': pd.Series([100, 92, 82, 79, 95, 91, 83, 80])}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   isimler  Ogr_No  Fizik  Matematik
# 0     Ali     100     90        100
# 1    Buse     101     88         92
# 2   Ceren     102     75         82
# 3   Deniz     103     92         79
# 4    Emre     104    100         95
# 5  Furkan     105     81         91
# 6   Gizem     106     77         83
# 7   Hakan     107     63         80

# %%
df['Fizik'].sum()
# Out:
# 666

# %%
df['Matematik'].mean()
# Out:
# 87.75

# %%
df['Fizik'].min()
# Out:
# 63

# %%
df['Matematik'].max()
# Out:
# 100

# %%
df.describe()
# Out:
#           Ogr_No       Fizik   Matematik
# count    8.00000    8.000000    8.000000
# mean   103.50000   83.250000   87.750000
# std      2.44949   11.634309    7.778175
# min    100.00000   63.000000   79.000000
# 25%    101.75000   76.500000   81.500000
# 50%    103.50000   84.500000   87.000000
# 75%    105.25000   90.500000   92.750000
# max    107.00000  100.000000  100.000000

# %%
df[df.Matematik > 90]["isimler"]
# Out:
# 0       Ali
# 1      Buse
# 4      Emre
# 5    Furkan
# Name: isimler, dtype: object
